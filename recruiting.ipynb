# %%
import TopDownHockey_Scraper.TopDownHockey_EliteProspects_Scraper as tdhepscrape
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
skaters = tdhepscrape.get_skaters(("ohl","whl","qmjhl"),("2023-2024"))
skaters = pd.DataFrame(skaters)
# Out:
# Your scrape request is skater data from the following leagues:
# ohl, qmjhl and whl
# In the following season:
# 2023-2024
# Beginning scrape of ohl skater data from 2023-2024.
# Successfully scraped all ohl skater data from 2023-2024.
# Scraping ohl data is complete. You scraped skater data from 2023-2024.
# Beginning scrape of whl skater data from 2023-2024.
# Successfully scraped all whl skater data from 2023-2024.
# Scraping whl data is complete. You scraped skater data from 2023-2024.
# Beginning scrape of qmjhl skater data from 2023-2024.
# Successfully scraped all qmjhl skater data from 2023-2024.
# Scraping qmjhl data is complete. You scraped skater data from 2023-2024.
# Completed scraping skater data from the following leagues:
# ohl, whl, and qmjhl
# Over the following season:
# 2023-2024

# %%
skaters
# Out:
#                      player                     team  gp   g   a   tp   ppg  \
# 0      David Goyette (C/LW)           Sudbury Wolves  68  40  77  117  1.72
# 1     Anthony Romani (RW/C)      North Bay Battalion  68  58  53  111  1.63
# 2       Dalyn Wakely (C/RW)      North Bay Battalion  66  39  65  104  1.58
# 3        Quentin Musty (LW)           Sudbury Wolves  53  43  59  102  1.92
# 4      Denver Barkey (C/LW)           London Knights  64  35  67  102  1.59
# ...                     ...                      ...  ..  ..  ..  ...   ...
# 1586       Jarrett Todd (C)  Charlottetown Islanders   9   0   0    0  0.00
# 1587  Zachary Robichaud (D)    Acadie-Bathurst Titan  11   0   0    0  0.00
# 1588    Jérémie Richard (D)      Saint John Sea Dogs  13   0   0    0  0.00
# 1589    Olivier Duhamel (D)      Saint John Sea Dogs  20   0   0    0  0.00
# 1590    Vincent Légaré (RW)       Sherbrooke Phoenix  20   0   0    0  0.00
#
#      pim  +/-                                               link     season  \
# 0     29   20  https://www.eliteprospects.com/player/562220/d...  2023-2024
# 1     20   43  https://www.eliteprospects.com/player/603107/a...  2023-2024
# 2     71   54  https://www.eliteprospects.com/player/620347/d...  2023-2024
# 3     72   19  https://www.eliteprospects.com/player/685701/q...  2023-2024
# 4     28   45  https://www.eliteprospects.com/player/723026/d...  2023-2024
# ...   ..  ...                                                ...        ...
# 1586   4   -6  https://www.eliteprospects.com/player/563381/j...  2023-2024
# 1587   2   -4  https://www.eliteprospects.com/player/618931/z...  2023-2024
# 1588   4   -2  https://www.eliteprospects.com/player/692527/j...  2023-2024
# 1589   4  -11  https://www.eliteprospects.com/player/878286/o...  2023-2024
# 1590   7   -8  https://www.eliteprospects.com/player/722842/v...  2023-2024
#
#      league             playername position
# 0       ohl   David Goyette (C/LW)     C/LW
# 1       ohl  Anthony Romani (RW/C)     RW/C
# 2       ohl    Dalyn Wakely (C/RW)     C/RW
# 3       ohl     Quentin Musty (LW)       LW
# 4       ohl   Denver Barkey (C/LW)     C/LW
# ...     ...                    ...      ...
# 1586  qmjhl       Jarrett Todd (C)        C
# 1587  qmjhl  Zachary Robichaud (D)        D
# 1588  qmjhl    Jérémie Richard (D)        D
# 1589  qmjhl    Olivier Duhamel (D)        D
# 1590  qmjhl    Vincent Légaré (RW)       RW
#
# [1591 rows x 14 columns]
